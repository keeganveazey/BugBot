# %%
# Libraries
import os
import shutil

"""
Run this script after image_processing_script.ipynb

Organizes insect image data into class folders.

This script creates folders for each insect class and moves images to their respective folders based on filename patterns.
Expects directory structure with 'TEST_DATA' and 'VALIDATION_DATA' subfolders, and organizes the images within these folders.
"""

# Directory constants
PROCESSED_DATA = "PROCESSED_DATA"
TEST_DATA = os.path.join(PROCESSED_DATA, "TEST_DATA")
VALIDATION_DATA = os.path.join(PROCESSED_DATA, "VALIDATION_DATA")

# Map of filename patterns to the correct class name
INSECT_CLASS_MAPPING = {
    "weevil": "adult_rice_weevil",
    "centipede": "house_centipede",
    "house_spider": "american_house_spider",
    "house_": "american_house_spider",
    "bedbug": "bedbug",
    "stink": "brown_stink_bug",
    "carpenterant": "carpenter_ant",
    "cellar": "cellar_spider",
    "flea": "flea",
    "silverfish": "silverfish",
    "termite": "subterranean_termite",
    "tick": "tick",
}

def organize_data(data_dir):
    """
    Create insect class folders and organize images to their correct folders
    """
    if not os.path.exists(data_dir):
        print(f"Directory {data_dir} does not exist!")
        return
    
    # Create class folders if doesnt exist
    for class_name in INSECT_CLASS_MAPPING.values():
        class_dir = os.path.join(data_dir, class_name)
        os.makedirs(class_dir, exist_ok=True)
    
    # Move images to their respective class folders
    for file_name in os.listdir(data_dir):
        file_path = os.path.join(data_dir, file_name)
        
        # Skip if it's already a directory
        if os.path.isdir(file_path):
            continue
        
        # Find correct class based on filename pattern
        for keyword, class_name in INSECT_CLASS_MAPPING.items():
            if keyword in file_name.lower():
                dest_path = os.path.join(data_dir, class_name, file_name)
                shutil.move(file_path, dest_path)
                print(f"Moved {file_name} → {dest_path}")
                break  # Stop checking once a match is found

# Organize the data in the TEST_DATA and VALIDATION_DATA folders
organize_data(TEST_DATA)
organize_data(VALIDATION_DATA)

print("TEST_DATA and VALIDATION_DATA have been organized into class folders.")
# Out:
# Moved image_75_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_75_tick_processed.jpg
# Moved reddit_cellar_36_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_36_processed.jpg
# Moved image_114_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_114_carpenterant_processed.jpg
# Moved image_95_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_95_flea_google_processed.jpg
# Moved image_77_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_77_carpenterant_processed.jpg
# Moved image_54_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_54_carpenterant_google_processed.jpg
# Moved image_78_flea_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_78_flea_processed.jpg
# Moved Image_5N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_5N_silverfish_processed.jpg
# Moved image_16_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_16_silverfish_reddit_processed.jpg
# Moved wiki_house_8_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/wiki_house_8_processed.jpg
# Moved image_118_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_118_bedbug_processed.jpg
# Moved image_27_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_27_carpenterant_google_processed.jpg
# Moved goog_weevil_16_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_16_processed.jpg
# Moved image_1_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_1_house_centipede_reddit_processed.jpg
# Moved image_100_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_100_tick_processed.jpg
# Moved image_65_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_65_tick_processed.jpg
# Moved goog_cellar_3_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/goog_cellar_3_processed.jpg
# Moved goog_weevil_12_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_12_processed.jpg
# Moved image_35_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_35_tick_google_processed.jpg
# Moved Image_33R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_33R_Bedbug_processed.jpg
# Moved reddit_cellar_2_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_2_processed.jpg
# Moved reddit_cellar_46_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_46_processed.jpg
# Moved image_72_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_72_american_house_spider_processed.jpg
# Moved image_93_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_93_tick_processed.jpg
# Moved image_11_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_11_flea_google_processed.jpg
# Moved image_4_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_4_bedbug_processed.jpg
# Moved goog_termite_26_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_26_processed.jpg
# Moved image_116_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_116_cellar_spider_processed.jpg
# Moved Image_43R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_43R_Bedbug_processed.jpg
# Moved Image_39N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_39N_silverfish_processed.jpg
# Moved image_28_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_28_tick_google_processed.jpg
# Moved image_150_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_150_tick_processed.jpg
# Moved image_16_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_16_brown_stink_bug_processed.jpg
# Moved Image_49R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_49R_Bedbug_processed.jpg
# Moved image_58_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_58_tick_google_processed.jpg
# Moved image_126_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_126_flea_google_processed.jpg
# Moved Image_49N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_49N_silverfish_processed.jpg
# Moved goog_termite_9_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_9_processed.jpg
# Moved image_69_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_69_flea_google_processed.jpg
# Moved image_87_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_87_flea_google_processed.jpg
# Moved image_30_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_30_flea_google_processed.jpg
# Moved image_79_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_79_bedbug_processed.jpg
# Moved image_68_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_68_brown_stink_bug_processed.jpg
# Moved Image_47R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_47R_house_centipede_processed.jpg
# Moved image_106_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_106_subterranean_termite_processed.jpg
# Moved goog_weevil_5_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_5_processed.jpg
# Moved Image_18N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_18N_silverfish_processed.jpg
# Moved Image_39R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_39R_Bedbug_processed.jpg
# Moved image_28_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_28_silverfish_reddit_processed.jpg
# Moved reddit_cellar_35_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_35_processed.jpg
# Moved image_122_house centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_122_house centipede_processed.jpg
# Moved Image_41R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_41R_Bedbug_processed.jpg
# Moved image_22_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_22_cellar_spider_processed.jpg
# Moved image_25_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_25_carpenterant_google_processed.jpg
# Moved image_125_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_125_house_centipede_processed.jpg
# Moved reddit_stink_39_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_39_processed.jpg
# Moved image_133_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_133_flea_google_processed.jpg
# Moved goog_weevil_28_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_28_processed.jpg
# Moved image_147_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_147_adult_rice_weevil_processed.jpg
# Moved image_106_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_106_silverfish_processed.jpg
# Moved image_52_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_52_flea_google_processed.jpg
# Moved goog_weevil_22_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_22_processed.jpg
# Moved image_115_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_115_tick_processed.jpg
# Moved goog_weevil_35_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_35_processed.jpg
# Moved image_60_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_60_tick_processed.jpg
# Moved image_88_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_88_tick_google_processed.jpg
# Moved image_106_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_106_house_centipede_processed.jpg
# Moved image_1_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_1_flea_google_processed.jpg
# Moved image_27_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_27_adult_rice_weevil_processed.jpg
# Moved image_16_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_16_cellar_spider_processed.jpg
# Moved reddit_house_24_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/reddit_house_24_processed.jpg
# Moved image_70_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_70_carpenterant_google_processed.jpg
# Moved wiki_house_1_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/wiki_house_1_processed.jpg
# Moved image_7_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_7_cellar_spider_processed.jpg
# Moved image_70_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_70_brown_stink_bug_processed.jpg
# Moved Image_32R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_32R_house_centipede_processed.jpg
# Moved image_40_flea_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_40_flea_processed.jpg
# Moved image_132_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_132_house_centipede_processed.jpg
# Moved image_22_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_22_tick_google_processed.jpg
# Moved goog_weevil_56_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_56_processed.jpg
# Moved goog_termite_96_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_96_processed.jpg
# Moved image_103_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_103_silverfish_processed.jpg
# Moved image_49_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_49_carpenterant_google_processed.jpg
# Moved image_109_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_109_house_centipede_processed.jpg
# Moved image_50_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_50_subterranean_termite_processed.jpg
# Moved image_86_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_86_carpenterant_processed.jpg
# Moved image_124_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_124_bedbug_processed.jpg
# Moved image_3_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_3_tick_google_processed.jpg
# Moved image_26_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_26_house_centipede_reddit_processed.jpg
# Moved image_81_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_81_carpenterant_processed.jpg
# Moved image_59_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_59_adult_rice_weevil_processed.jpg
# Moved image_2_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_2_silverfish_reddit_processed.jpg
# Moved image_115_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_115_subterranean_termite_processed.jpg
# Moved image_95_flea_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_95_flea_processed.jpg
# Moved image_59_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_59_carpenterant_processed.jpg
# Moved image_2_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_2_subterranean_termite_processed.jpg
# Moved image_86_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_86_american_house_spider_processed.jpg
# Moved image_129_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_129_american_house_spider_processed.jpg
# Moved image_8_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_8_brown_stink_bug_processed.jpg
# Moved image_119_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_119_silverfish_processed.jpg
# Moved wiki_house_11_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/wiki_house_11_processed.jpg
# Moved image_87_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_87_tick_google_processed.jpg
# Moved Image_8N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_8N_silverfish_processed.jpg
# Moved reddit_stink_30_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_30_processed.jpg
# Moved image_127_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_127_brown_stink_bug_processed.jpg
# Moved image_115_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_115_silverfish_processed.jpg
# Moved image_30_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_30_american_house_spider_processed.jpg
# Moved image_139_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_139_brown_stink_bug_processed.jpg
# Moved Image_5R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_5R_house_centipede_processed.jpg
# Moved image_7_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_7_brown_stink_bug_processed.jpg
# Moved image_39_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_39_bedbug_processed.jpg
# Moved image_48_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_48_cellar_spider_processed.jpg
# Moved image_46_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_46_carpenterant_google_processed.jpg
# Moved wiki_house_2_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/wiki_house_2_processed.jpg
# Moved image_61_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_61_cellar_spider_processed.jpg
# Moved Image_16R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_16R_Bedbug_processed.jpg
# Moved image_39_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_39_tick_google_processed.jpg
# Moved goog_termite_29_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_29_processed.jpg
# Moved image_10_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_10_adult_rice_weevil_processed.jpg
# Moved image_102_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_102_house_centipede_processed.jpg
# Moved image_31_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_31_tick_google_processed.jpg
# Moved image_77_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_77_flea_google_processed.jpg
# Moved image_58_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_58_american_house_spider_processed.jpg
# Moved image_40_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_40_brown_stink_bug_processed.jpg
# Moved image_110_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_110_brown_stink_bug_processed.jpg
# Moved Image_22R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_22R_house_centipede_processed.jpg
# Moved goog_termite_87_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_87_processed.jpg
# Moved image_82_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_82_cellar_spider_processed.jpg
# Moved image_117_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_117_tick_processed.jpg
# Moved Image_35N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_35N_silverfish_processed.jpg
# Moved goog_termite_77_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_77_processed.jpg
# Moved image_74_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_74_brown_stink_bug_processed.jpg
# Moved image_141_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_141_american_house_spider_processed.jpg
# Moved image_102_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_102_subterranean_termite_processed.jpg
# Moved image_124_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_124_adult_rice_weevil_processed.jpg
# Moved image_130_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_130_bedbug_processed.jpg
# Moved image_150_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_150_silverfish_processed.jpg
# Moved image_58_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_58_cellar_spider_processed.jpg
# Moved image_68_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_68_carpenterant_google_processed.jpg
# Moved image_101_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_101_brown_stink_bug_processed.jpg
# Moved goog_termite_73_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_73_processed.jpg
# Moved image_34_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_34_adult_rice_weevil_processed.jpg
# Moved image_72_tick_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_72_tick_processed.jpg
# Moved image_32_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_32_subterranean_termite_processed.jpg
# Moved goog_weevil_37_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_37_processed.jpg
# Moved reddit_cellar_10_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_10_processed.jpg
# Moved image_81_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_81_american_house_spider_processed.jpg
# Moved image_15_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_15_house_centipede_reddit_processed.jpg
# Moved reddit_stink_18_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_18_processed.jpg
# Moved Image_6R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_6R_house_centipede_processed.jpg
# Moved reddit_stink_36_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_36_processed.jpg
# Moved image_87_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_87_adult_rice_weevil_processed.jpg
# Moved image_63_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_63_bedbug_processed.jpg
# Moved image_11_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_11_silverfish_reddit_processed.jpg
# Moved Image_32N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_32N_silverfish_processed.jpg
# Moved image_29_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_29_flea_google_processed.jpg
# Moved goog_termite_13_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_13_processed.jpg
# Moved image_45_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_45_house_centipede_reddit_processed.jpg
# Moved image_31_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_31_carpenterant_google_processed.jpg
# Moved image_115_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_115_bedbug_processed.jpg
# Moved Image_26R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_26R_Bedbug_processed.jpg
# Moved image_81_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_81_tick_google_processed.jpg
# Moved image_8_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_8_house_centipede_reddit_processed.jpg
# Moved goog_termite_17_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_17_processed.jpg
# Moved image_65_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_65_house_centipede_reddit_processed.jpg
# Moved image_28_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_28_carpenterant_processed.jpg
# Moved image_99_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_99_brown_stink_bug_processed.jpg
# Moved reddit_stink_42_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_42_processed.jpg
# Moved image_43_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_43_silverfish_reddit_processed.jpg
# Moved image_11_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_11_carpenterant_processed.jpg
# Moved image_17_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_17_carpenterant_google_processed.jpg
# Moved goog_weevil_60_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_60_processed.jpg
# Moved image_132_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_132_flea_google_processed.jpg
# Moved reddit_cellar_40_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_40_processed.jpg
# Moved Image_22N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_22N_silverfish_processed.jpg
# Moved goog_house_13_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/goog_house_13_processed.jpg
# Moved Image_36R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_36R_Bedbug_processed.jpg
# Moved image_82_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_82_carpenterant_google_processed.jpg
# Moved image_23_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_23_carpenterant_google_processed.jpg
# Moved image_14G_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_14G_bedbug_processed.jpg
# Moved goog_weevil_10_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_10_processed.jpg
# Moved reddit_stink_16_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_16_processed.jpg
# Moved image_3_carpenterant_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_3_carpenterant_processed.jpg
# Moved reddit_house_12_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/reddit_house_12_processed.jpg
# Moved goog_termite_43_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_43_processed.jpg
# Moved image_127_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_127_flea_google_processed.jpg
# Moved image_38_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_38_subterranean_termite_processed.jpg
# Moved Image_46R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_46R_Bedbug_processed.jpg
# Moved image_134_brown_stink_bug_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/image_134_brown_stink_bug_processed.jpg
# Moved reddit_cellar_34_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/reddit_cellar_34_processed.jpg
# Moved image_24_silverfish_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/image_24_silverfish_reddit_processed.jpg
# Moved image_67_flea_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_67_flea_processed.jpg
# Moved reddit_stink_15_processed.jpg → PROCESSED_DATA/TEST_DATA/brown_stink_bug/reddit_stink_15_processed.jpg
# Moved goog_termite_79_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_79_processed.jpg
# Moved image_70_tick_google_processed.jpg → PROCESSED_DATA/TEST_DATA/tick/image_70_tick_google_processed.jpg
# Moved reddit_house_11_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/reddit_house_11_processed.jpg
# Moved image_99_subterranean_termite_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/image_99_subterranean_termite_processed.jpg
# Moved image_9_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_9_american_house_spider_processed.jpg
# Moved image_69_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_69_house_centipede_reddit_processed.jpg
# Moved image_18_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_18_flea_google_processed.jpg
# Moved image_14_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_14_cellar_spider_processed.jpg
# Moved goog_cellar_6_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/goog_cellar_6_processed.jpg
# Moved image_56_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_56_adult_rice_weevil_processed.jpg
# Moved image_49_house_centipede_reddit_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/image_49_house_centipede_reddit_processed.jpg
# Moved goog_termite_53_processed.jpg → PROCESSED_DATA/TEST_DATA/subterranean_termite/goog_termite_53_processed.jpg
# Moved reddit_house_15_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/reddit_house_15_processed.jpg
# Moved image_126_bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/image_126_bedbug_processed.jpg
# Moved image_134_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_134_american_house_spider_processed.jpg
# Moved goog_weevil_7_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/goog_weevil_7_processed.jpg
# Moved image_113_flea_google_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_113_flea_google_processed.jpg
# Moved Image_18R_house_centipede_processed.jpg → PROCESSED_DATA/TEST_DATA/house_centipede/Image_18R_house_centipede_processed.jpg
# Moved Image_25N_silverfish_processed.jpg → PROCESSED_DATA/TEST_DATA/silverfish/Image_25N_silverfish_processed.jpg
# Moved Image_52R_Bedbug_processed.jpg → PROCESSED_DATA/TEST_DATA/bedbug/Image_52R_Bedbug_processed.jpg
# Moved image_106_cellar_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/image_106_cellar_spider_processed.jpg
# Moved image_41_adult_rice_weevil_processed.jpg → PROCESSED_DATA/TEST_DATA/adult_rice_weevil/image_41_adult_rice_weevil_processed.jpg
# Moved image_15_american_house_spider_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/image_15_american_house_spider_processed.jpg
# Moved goog_cellar_17_processed.jpg → PROCESSED_DATA/TEST_DATA/cellar_spider/goog_cellar_17_processed.jpg
# Moved image_59_flea_processed.jpg → PROCESSED_DATA/TEST_DATA/flea/image_59_flea_processed.jpg
# Moved goog_house_6_processed.jpg → PROCESSED_DATA/TEST_DATA/american_house_spider/goog_house_6_processed.jpg
# Moved image_15_carpenterant_google_processed.jpg → PROCESSED_DATA/TEST_DATA/carpenter_ant/image_15_carpenterant_google_processed.jpg
# Moved image_118_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_118_silverfish_processed.jpg
# Moved reddit_house_14_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/reddit_house_14_processed.jpg
# Moved image_108_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_108_house_centipede_processed.jpg
# Moved image_55_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_55_flea_google_processed.jpg
# Moved image_1_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_1_brown_stink_bug_processed.jpg
# Moved image_120_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_120_bedbug_processed.jpg
# Moved reddit_cellar_21_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_21_processed.jpg
# Moved image_97_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_97_house_centipede_processed.jpg
# Moved reddit_stink_10_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_10_processed.jpg
# Moved image_45_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_45_carpenterant_google_processed.jpg
# Moved image_68_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_68_tick_processed.jpg
# Moved reddit_cellar_25_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_25_processed.jpg
# Moved image_133_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_133_house_centipede_processed.jpg
# Moved image_112_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_112_flea_google_processed.jpg
# Moved image_3_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_3_flea_google_processed.jpg
# Moved goog_termite_41_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_41_processed.jpg
# Moved image_60_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_60_silverfish_reddit_processed.jpg
# Moved image_60_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_60_carpenterant_google_processed.jpg
# Moved image_112_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_112_bedbug_processed.jpg
# Moved wiki_house_22_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_22_processed.jpg
# Moved image_107_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_107_flea_google_processed.jpg
# Moved goog_termite_35_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_35_processed.jpg
# Moved image_114_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_114_american_house_spider_processed.jpg
# Moved image_43_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_43_subterranean_termite_processed.jpg
# Moved image_86_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_86_house_centipede_processed.jpg
# Moved image_1G_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_1G_bedbug_processed.jpg
# Moved image_3_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_3_cellar_spider_processed.jpg
# Moved goog_weevil_2_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_2_processed.jpg
# Moved image_66_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_66_flea_google_processed.jpg
# Moved image_11G_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_11G_bedbug_processed.jpg
# Moved image_98_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_98_house_centipede_processed.jpg
# Moved image_32_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_32_silverfish_reddit_processed.jpg
# Moved image_59_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_59_carpenterant_google_processed.jpg
# Moved image_56_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_56_silverfish_reddit_processed.jpg
# Moved image_112_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_112_subterranean_termite_processed.jpg
# Moved image_37_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_37_flea_google_processed.jpg
# Moved Image_20R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_20R_house_centipede_processed.jpg
# Moved Image_55R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_55R_Bedbug_processed.jpg
# Moved image_26_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_26_american_house_spider_processed.jpg
# Moved image_107_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_107_american_house_spider_processed.jpg
# Moved image_31_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_31_carpenterant_processed.jpg
# Moved image_48_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_48_carpenterant_google_processed.jpg
# Moved goog_weevil_6_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_6_processed.jpg
# Moved image_107_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_107_adult_rice_weevil_processed.jpg
# Moved image_133_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_133_tick_processed.jpg
# Moved wiki_house_21_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_21_processed.jpg
# Moved image_57_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_57_subterranean_termite_processed.jpg
# Moved Image_31R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_31R_Bedbug_processed.jpg
# Moved image_31_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_31_cellar_spider_processed.jpg
# Moved image_52_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_52_adult_rice_weevil_processed.jpg
# Moved Image_41R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_41R_house_centipede_processed.jpg
# Moved image_111_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_111_house_centipede_processed.jpg
# Moved image_96_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_96_cellar_spider_processed.jpg
# Moved image_108_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_108_flea_google_processed.jpg
# Moved goog_termite_25_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_25_processed.jpg
# Moved reddit_cellar_56_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_56_processed.jpg
# Moved reddit_cellar_41_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_41_processed.jpg
# Moved image_16_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_16_flea_google_processed.jpg
# Moved image_100_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_100_bedbug_processed.jpg
# Moved image_27_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_27_cellar_spider_processed.jpg
# Moved image_100_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_100_flea_google_processed.jpg
# Moved image_8_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_8_subterranean_termite_processed.jpg
# Moved image_115_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_115_adult_rice_weevil_processed.jpg
# Moved image_93_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_93_cellar_spider_processed.jpg
# Moved image_9_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_9_brown_stink_bug_processed.jpg
# Moved image_36_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_36_american_house_spider_processed.jpg
# Moved image_57_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_57_adult_rice_weevil_processed.jpg
# Moved Image_4R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_4R_house_centipede_processed.jpg
# Moved image_85_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_85_tick_google_processed.jpg
# Moved Image_137_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_137_bedbug_processed.jpg
# Moved image_33_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_33_adult_rice_weevil_processed.jpg
# Moved image_62_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_62_carpenterant_google_processed.jpg
# Moved image_19_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_19_subterranean_termite_processed.jpg
# Moved goog_weevil_15_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_15_processed.jpg
# Moved image_105_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_105_carpenterant_processed.jpg
# Moved image_115_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_115_flea_google_processed.jpg
# Moved image_76_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_76_bedbug_processed.jpg
# Moved image_73_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_73_subterranean_termite_processed.jpg
# Moved image_109_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_109_carpenterant_processed.jpg
# Moved Image_17R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_17R_house_centipede_processed.jpg
# Moved image_132_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_132_bedbug_processed.jpg
# Moved Image_2R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_2R_house_centipede_processed.jpg
# Moved image_110_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_110_adult_rice_weevil_processed.jpg
# Moved image_84_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_84_carpenterant_google_processed.jpg
# Moved Image_2N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_2N_silverfish_processed.jpg
# Moved image_113_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_113_carpenterant_processed.jpg
# Moved image_12_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_12_american_house_spider_processed.jpg
# Moved image_123_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_123_adult_rice_weevil_processed.jpg
# Moved image_129_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_129_brown_stink_bug_processed.jpg
# Moved image_92_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_92_flea_google_processed.jpg
# Moved image_25_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_25_flea_google_processed.jpg
# Moved image_21_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_21_adult_rice_weevil_processed.jpg
# Moved Image_15R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_15R_Bedbug_processed.jpg
# Moved image_5_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_5_adult_rice_weevil_processed.jpg
# Moved image_15_flea_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_15_flea_processed.jpg
# Moved image_34_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_34_carpenterant_google_processed.jpg
# Moved goog_weevil_11_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_11_processed.jpg
# Moved image_131_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_131_silverfish_processed.jpg
# Moved image_20_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_20_flea_google_processed.jpg
# Moved reddit_stink_33_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_33_processed.jpg
# Moved image_87_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_87_carpenterant_google_processed.jpg
# Moved image_96_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_96_american_house_spider_processed.jpg
# Moved image_44_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_44_carpenterant_google_processed.jpg
# Moved goog_termite_48_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_48_processed.jpg
# Moved reddit_stink_24_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_24_processed.jpg
# Moved image_101_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_101_cellar_spider_processed.jpg
# Moved image_62_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_62_adult_rice_weevil_processed.jpg
# Moved goog_termite_66_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_66_processed.jpg
# Moved Image_13R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_13R_Bedbug_processed.jpg
# Moved image_5G_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_5G_bedbug_processed.jpg
# Moved goog_termite_71_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_71_processed.jpg
# Moved image_79_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_79_flea_google_processed.jpg
# Moved reddit_house_20_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/reddit_house_20_processed.jpg
# Moved image_24_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_24_brown_stink_bug_processed.jpg
# Moved goog_weevil_31_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_31_processed.jpg
# Moved image_61_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_61_carpenterant_google_processed.jpg
# Moved image_85_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_85_american_house_spider_processed.jpg
# Moved image_27_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_27_house_centipede_reddit_processed.jpg
# Moved image_30_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_30_house_centipede_reddit_processed.jpg
# Moved image_3_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_3_adult_rice_weevil_processed.jpg
# Moved goog_termite_101_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_101_processed.jpg
# Moved reddit_stink_37_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_37_processed.jpg
# Moved image_28_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_28_flea_google_processed.jpg
# Moved image_82_brown stink bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_82_brown stink bug_processed.jpg
# Moved image_14_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_14_adult_rice_weevil_processed.jpg
# Moved image_71_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_71_flea_google_processed.jpg
# Moved image_95_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_95_brown_stink_bug_processed.jpg
# Moved image_116_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_116_adult_rice_weevil_processed.jpg
# Moved image_116_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_116_bedbug_processed.jpg
# Moved image_80_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_80_tick_google_processed.jpg
# Moved image_37_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_37_tick_google_processed.jpg
# Moved Image_29R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_29R_Bedbug_processed.jpg
# Moved image_70_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_70_tick_processed.jpg
# Moved image_105_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_105_flea_google_processed.jpg
# Moved image_107_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_107_silverfish_processed.jpg
# Moved image_43_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_43_american_house_spider_processed.jpg
# Moved goog_cellar_22_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/goog_cellar_22_processed.jpg
# Moved reddit_stink_43_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_43_processed.jpg
# Moved image_64_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_64_flea_google_processed.jpg
# Moved image_104_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_104_cellar_spider_processed.jpg
# Moved wiki_house_16_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_16_processed.jpg
# Moved image_42_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_42_cellar_spider_processed.jpg
# Moved Image_33N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_33N_silverfish_processed.jpg
# Moved image_98_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_98_silverfish_processed.jpg
# Moved image_113_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_113_subterranean_termite_processed.jpg
# Moved image_101_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_101_american_house_spider_processed.jpg
# Moved goog_termite_3_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_3_processed.jpg
# Moved Image_21R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_21R_Bedbug_processed.jpg
# Moved image_65_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_65_bedbug_processed.jpg
# Moved reddit_stink_47_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_47_processed.jpg
# Moved image_11_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_11_adult_rice_weevil_processed.jpg
# Moved image_99_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_99_american_house_spider_processed.jpg
# Moved reddit_stink_50_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_50_processed.jpg
# Moved Image_27R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_27R_house_centipede_processed.jpg
# Moved image_88_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_88_house_centipede_processed.jpg
# Moved image_33_flea_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_33_flea_processed.jpg
# Moved image_123_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_123_flea_google_processed.jpg
# Moved image_96_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_96_house_centipede_processed.jpg
# Moved image_146_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_146_tick_processed.jpg
# Moved reddit_stink_40_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_40_processed.jpg
# Moved image_95_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_95_tick_processed.jpg
# Moved image_124_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_124_flea_google_processed.jpg
# Moved reddit_cellar_48_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_48_processed.jpg
# Moved image_38_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_38_carpenterant_google_processed.jpg
# Moved goog_termite_86_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_86_processed.jpg
# Moved image_126_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_126_tick_processed.jpg
# Moved image_36_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_36_house_centipede_reddit_processed.jpg
# Moved image_32_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_32_flea_google_processed.jpg
# Moved image_37_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_37_subterranean_termite_processed.jpg
# Moved goog_termite_82_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_82_processed.jpg
# Moved image_55_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_55_carpenterant_processed.jpg
# Moved image_84_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_84_cellar_spider_processed.jpg
# Moved image_14_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_14_flea_google_processed.jpg
# Moved image_72_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_72_bedbug_processed.jpg
# Moved reddit_stink_44_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_44_processed.jpg
# Moved goog_termite_28_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_28_processed.jpg
# ...
# Moved Image_27N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_27N_silverfish_processed.jpg
# Moved goog_termite_97_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_97_processed.jpg
# Moved image_20_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_20_carpenterant_google_processed.jpg
# Moved image_81_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_81_carpenterant_google_processed.jpg
# Moved image_42_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_42_house_centipede_reddit_processed.jpg
# Moved image_2_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_2_carpenterant_processed.jpg
# Moved reddit_cellar_59_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_59_processed.jpg
# Moved image_116_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_116_american_house_spider_processed.jpg
# Moved image_87_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_87_tick_processed.jpg
# Moved image_21_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_21_flea_google_processed.jpg
# Moved image_134_flea_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_134_flea_processed.jpg
# Moved image_47_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_47_american_house_spider_processed.jpg
# Moved image_128_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_128_silverfish_processed.jpg
# Moved goog_weevil_53_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_53_processed.jpg
# Moved goog_cellar_23_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/goog_cellar_23_processed.jpg
# Moved image_106_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_106_brown_stink_bug_processed.jpg
# Moved goog_termite_84_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_84_processed.jpg
# Moved image_110_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_110_bedbug_processed.jpg
# Moved image_49_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_49_tick_google_processed.jpg
# Moved image_122_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_122_tick_processed.jpg
# Moved Image_3N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_3N_silverfish_processed.jpg
# Moved image_109_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_109_bedbug_processed.jpg
# Moved image_93_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_93_flea_google_processed.jpg
# Moved image_24_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_24_flea_google_processed.jpg
# Moved image_56_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_56_carpenterant_processed.jpg
# Moved image_100_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_100_brown_stink_bug_processed.jpg
# Moved image_91_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_91_tick_processed.jpg
# Moved Image_23R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_23R_house_centipede_processed.jpg
# Moved image_33_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_33_silverfish_reddit_processed.jpg
# Moved wiki_house_24_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_24_processed.jpg
# Moved reddit_cellar_57_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_57_processed.jpg
# Moved image_145_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_145_brown_stink_bug_processed.jpg
# Moved image_57_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_57_silverfish_reddit_processed.jpg
# Moved image_32_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_32_carpenterant_google_processed.jpg
# Moved image_21_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_21_silverfish_reddit_processed.jpg
# Moved image_137_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_137_house_centipede_processed.jpg
# Moved goog_house_9_copy_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/goog_house_9_copy_processed.jpg
# Moved goog_cellar_14_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/goog_cellar_14_processed.jpg
# Moved image_33_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_33_tick_google_processed.jpg
# Moved image_115_house centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_115_house centipede_processed.jpg
# Moved image_68_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_68_house_centipede_reddit_processed.jpg
# Moved image_41_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_41_carpenterant_google_processed.jpg
# Moved wiki_house_20_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_20_processed.jpg
# Moved image_109_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_109_cellar_spider_processed.jpg
# Moved goog_termite_20_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/goog_termite_20_processed.jpg
# Moved Image_36R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_36R_house_centipede_processed.jpg
# Moved goog_house_5_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/goog_house_5_processed.jpg
# Moved image_51_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_51_tick_google_processed.jpg
# Moved Image_37N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_37N_silverfish_processed.jpg
# Moved image_40_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_40_subterranean_termite_processed.jpg
# Moved image_36_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_36_silverfish_reddit_processed.jpg
# Moved image_17_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_17_flea_google_processed.jpg
# Moved image_4G_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_4G_bedbug_processed.jpg
# Moved image_4_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_4_carpenterant_google_processed.jpg
# Moved image_16_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_16_american_house_spider_processed.jpg
# Moved image_102_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_102_tick_processed.jpg
# Moved goog_weevil_29_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_29_processed.jpg
# Moved reddit_stink_38_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_38_processed.jpg
# Moved image_103_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_103_subterranean_termite_processed.jpg
# Moved image_142_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_142_bedbug_processed.jpg
# Moved reddit_stink_12_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/reddit_stink_12_processed.jpg
# Moved goog_cellar_5_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/goog_cellar_5_processed.jpg
# Moved Image_48N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_48N_silverfish_processed.jpg
# Moved image_59_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_59_subterranean_termite_processed.jpg
# Moved Image_50R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_50R_Bedbug_processed.jpg
# Moved image_40_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_40_silverfish_reddit_processed.jpg
# Moved image_24_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_24_cellar_spider_processed.jpg
# Moved image_112_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_112_tick_processed.jpg
# Moved image_77_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_77_tick_google_processed.jpg
# Moved image_79_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_79_american_house_spider_processed.jpg
# Moved image_103_cellar_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/image_103_cellar_spider_processed.jpg
# Moved image_98_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_98_brown_stink_bug_processed.jpg
# Moved goog_weevil_13_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_13_processed.jpg
# Moved image_104_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_104_silverfish_processed.jpg
# Moved image_4_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_4_adult_rice_weevil_processed.jpg
# Moved Image_16N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_16N_silverfish_processed.jpg
# Moved image_81_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_81_flea_google_processed.jpg
# Moved image_77_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_77_adult_rice_weevil_processed.jpg
# Moved image_120_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_120_flea_google_processed.jpg
# Moved image_111_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_111_tick_processed.jpg
# Moved image_13_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_13_adult_rice_weevil_processed.jpg
# Moved image_4_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_4_house_centipede_reddit_processed.jpg
# Moved Image_38N_silverfish_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/Image_38N_silverfish_processed.jpg
# Moved Image_48R_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/Image_48R_house_centipede_processed.jpg
# Moved image_6_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_6_carpenterant_google_processed.jpg
# Moved image_103_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_103_adult_rice_weevil_processed.jpg
# Moved image_150_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_150_bedbug_processed.jpg
# Moved reddit_cellar_20_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_20_processed.jpg
# Moved image_29_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_29_silverfish_reddit_processed.jpg
# Moved goog_weevil_39_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/goog_weevil_39_processed.jpg
# Moved image_56_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_56_tick_google_processed.jpg
# Moved Image_8R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_8R_Bedbug_processed.jpg
# Moved reddit_cellar_37_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_37_processed.jpg
# Moved image_70_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_70_subterranean_termite_processed.jpg
# Moved image_104_house_centipede_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_104_house_centipede_processed.jpg
# Moved image_29_house_centipede_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/house_centipede/image_29_house_centipede_reddit_processed.jpg
# Moved image_21_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_21_carpenterant_google_processed.jpg
# Moved image_89_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_89_carpenterant_processed.jpg
# Moved Image_44R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_44R_Bedbug_processed.jpg
# Moved image_131_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_131_tick_processed.jpg
# Moved reddit_house_9_5_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/reddit_house_9_5_processed.jpg
# Moved image_111_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_111_carpenterant_processed.jpg
# Moved image_34_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_34_tick_google_processed.jpg
# Moved reddit_cellar_7_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_7_processed.jpg
# Moved image_52_carpenterant_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_52_carpenterant_google_processed.jpg
# Moved image_89_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_89_brown_stink_bug_processed.jpg
# Moved image_11_subterranean_termite_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/subterranean_termite/image_11_subterranean_termite_processed.jpg
# Moved image_127_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_127_adult_rice_weevil_processed.jpg
# Moved image_1_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_1_adult_rice_weevil_processed.jpg
# Moved image_25_adult_rice_weevil_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/adult_rice_weevil/image_25_adult_rice_weevil_processed.jpg
# Moved image_8_silverfish_reddit_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/silverfish/image_8_silverfish_reddit_processed.jpg
# Moved image_54_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_54_flea_google_processed.jpg
# Moved image_142_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_142_tick_processed.jpg
# Moved image_93_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_93_carpenterant_processed.jpg
# Moved Image_10R_Bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/Image_10R_Bedbug_processed.jpg
# Moved image_12_tick_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_12_tick_google_processed.jpg
# Moved image_6G_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_6G_bedbug_processed.jpg
# Moved image_23_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_23_flea_google_processed.jpg
# Moved image_94_flea_google_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_94_flea_google_processed.jpg
# Moved image_92_tick_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/tick/image_92_tick_processed.jpg
# Moved image_68_carpenterant_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/carpenter_ant/image_68_carpenterant_processed.jpg
# Moved image_110_american_house_spider_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/image_110_american_house_spider_processed.jpg
# Moved image_62_bedbug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/bedbug/image_62_bedbug_processed.jpg
# Moved image_63_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_63_brown_stink_bug_processed.jpg
# Moved image_121_flea_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/flea/image_121_flea_processed.jpg
# Moved wiki_house_23_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/american_house_spider/wiki_house_23_processed.jpg
# Moved reddit_cellar_50_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/cellar_spider/reddit_cellar_50_processed.jpg
# Moved image_133_brown_stink_bug_processed.jpg → PROCESSED_DATA/VALIDATION_DATA/brown_stink_bug/image_133_brown_stink_bug_processed.jpg
# TEST_DATA and VALIDATION_DATA have been organized into class folders.
